# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.mixture import GaussianMixture
from sklearn import metrics
import random
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from matplotlib.pyplot import figure
from sklearn.cluster import KMeans

n_clusters = 2
k1 = 32
k2 = 16

center = 3
dev = 1
n_points = 100
cluster = [None]*6

cluster[0] = np.random.normal(0, dev, (n_points,2))
cluster[1] = np.random.normal(center, dev, (n_points,2))
cluster[2] = np.random.normal(-center, dev, (n_points,2))
cluster[3] = np.concatenate((np.random.normal(-center, dev, (n_points,1)),np.random.normal(center, dev, (n_points,1))), axis=1)
cluster[4] = np.concatenate((np.random.normal(-2*center, dev, (n_points,1)),np.random.normal(0, dev, (n_points,1))), axis=1)
cluster[5] = np.concatenate((np.random.normal(center, dev, (n_points,1)),np.random.normal(-center, dev, (n_points,1))), axis=1)

noise1 = np.random.uniform(low=-8, high=8, size = n_clusters*n_points)
noise2 = np.random.uniform(low=-8, high=8, size = n_clusters*n_points)

X_train = cluster[0]
for i in range(1,n_clusters):
    X_train = np.concatenate((X_train,cluster[i]))

X_train = shuffle(X_train, random_state=0)

plt.scatter(X_train[:,0], X_train[:,1], c='red')

X_train = np.column_stack((X_train, noise1))
X_train = np.column_stack((X_train, noise2))

# %%
import torch
from torch import nn, optim
import torch.nn.functional as F

device = torch.device("cpu")

class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, X_train):
        X = torch.from_numpy(X_train).float()
        X.requires_grad=True
        self.X = X.to(device)


    def __len__(self):
        return len(self.X)

    def __getitem__(self, index):
        return self.X[index]
    
train_data = CustomDataset(X_train)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=10*n_clusters)

class Net(nn.Module):

    def __init__(self, n_features):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_features, k1, bias=True)
        self.fc2 = nn.Linear(k1, n_clusters, bias=True)

    def forward(self, x):
        x = nn.functional.relu(self.fc1(x))
        return F.softmin(self.fc2(x))

net = Net(4)

net = net.to(device)

# %%
def silhouette(X, y):
    distances = torch.cdist(X, X, p=0.1)
    weighted_distances = torch.matmul(distances, y)
    sum_p = torch.sum(y, dim = 0)
    sum_p_mat = torch.empty(y.shape[0], y.shape[1])
    for i in range(y.shape[0]):
        sum_p_mat[i] = sum_p - y[i]
    alphas = torch.div(weighted_distances, sum_p)
    betas = torch.empty(alphas.shape[0], alphas.shape[1])
    betas = betas.to(device)
    for i in range(alphas.shape[0]):
        for j in range(alphas.shape[1]):
            betas[i][j] = min([alphas[i][x] for x in range(alphas.shape[1]) if x!=j])
    max_ab = torch.max(alphas, betas)
    s = betas - alphas
    s = torch.div(s, max_ab)
    s = s*y
    s = torch.sum(s, dim=1)
    s = torch.mean(s)
    return s

# %%
y_true = []
X_simple = np.delete(X_train, 2, 1)
X_simple = np.delete(X_simple, 2, 1)
for x in X_simple:
    for i in range(len(cluster)):
        if len(np.where(cluster[i] == x)[0])>0:
            y_true.append(i)

# %%
true = np.zeros((len(X_train), n_clusters))
for i in range(len(X_train)):
    true[i][y_true[i]] = 1

print(silhouette(torch.from_numpy(X_train).float(), torch.from_numpy(true).float()))
# Out:
# tensor(0.3767)

# %%
optimizer = optim.Adam(net.parameters(), lr=0.3)
train_data = CustomDataset(X_train)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=int(n_points*n_clusters/1))

for epoch in range(100):
    for n, X in enumerate(train_loader):
        y = net(X)
        y = torch.squeeze(y)
        s = silhouette(X, y)
        s = (1 - s)

        loss = s 
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print(epoch)
    print(1 - s)
# Out:
# 0
# tensor(0.0104, grad_fn=<RsubBackward1>)
# <ipython-input-2-d90c5a287120>:32: UserWarning: Implicit dimension choice for softmin has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmin(self.fc2(x))
# 1
# tensor(0.1930, grad_fn=<RsubBackward1>)
# 2
# tensor(0.2363, grad_fn=<RsubBackward1>)
# 3
# tensor(0.2409, grad_fn=<RsubBackward1>)
# 4
# tensor(0.2640, grad_fn=<RsubBackward1>)
# 5
# tensor(0.3080, grad_fn=<RsubBackward1>)
# 6
# tensor(0.3438, grad_fn=<RsubBackward1>)
# 7
# tensor(0.2645, grad_fn=<RsubBackward1>)
# 8
# tensor(0.3391, grad_fn=<RsubBackward1>)
# 9
# tensor(0.3287, grad_fn=<RsubBackward1>)
# 10
# tensor(0.3196, grad_fn=<RsubBackward1>)
# 11
# tensor(0.3100, grad_fn=<RsubBackward1>)
# 12
# tensor(0.3315, grad_fn=<RsubBackward1>)
# 13
# tensor(0.3331, grad_fn=<RsubBackward1>)
# 14
# tensor(0.3443, grad_fn=<RsubBackward1>)
# 15
# tensor(0.3434, grad_fn=<RsubBackward1>)
# 16
# tensor(0.3495, grad_fn=<RsubBackward1>)
# 17
# tensor(0.3555, grad_fn=<RsubBackward1>)
# 18
# tensor(0.3556, grad_fn=<RsubBackward1>)
# 19
# tensor(0.3512, grad_fn=<RsubBackward1>)
# 20
# tensor(0.3400, grad_fn=<RsubBackward1>)
# 21
# tensor(0.3439, grad_fn=<RsubBackward1>)
# 22
# tensor(0.3494, grad_fn=<RsubBackward1>)
# 23
# tensor(0.3396, grad_fn=<RsubBackward1>)
# 24
# tensor(0.3498, grad_fn=<RsubBackward1>)
# 25
# tensor(0.3676, grad_fn=<RsubBackward1>)
# 26
# tensor(0.3790, grad_fn=<RsubBackward1>)
# 27
# tensor(0.3805, grad_fn=<RsubBackward1>)
# 28
# tensor(0.3741, grad_fn=<RsubBackward1>)
# 29
# tensor(0.3652, grad_fn=<RsubBackward1>)
# 30
# tensor(0.3627, grad_fn=<RsubBackward1>)
# 31
# tensor(0.3553, grad_fn=<RsubBackward1>)
# 32
# tensor(0.3471, grad_fn=<RsubBackward1>)
# 33
# tensor(0.3411, grad_fn=<RsubBackward1>)
# 34
# tensor(0.3417, grad_fn=<RsubBackward1>)
# 35
# tensor(0.3457, grad_fn=<RsubBackward1>)
# 36
# tensor(0.3489, grad_fn=<RsubBackward1>)
# 37
# tensor(0.3524, grad_fn=<RsubBackward1>)
# 38
# tensor(0.3623, grad_fn=<RsubBackward1>)
# 39
# tensor(0.3666, grad_fn=<RsubBackward1>)
# 40
# tensor(0.3710, grad_fn=<RsubBackward1>)
# 41
# tensor(0.3710, grad_fn=<RsubBackward1>)
# 42
# tensor(0.3761, grad_fn=<RsubBackward1>)
# 43
# tensor(0.3726, grad_fn=<RsubBackward1>)
# 44
# tensor(0.3716, grad_fn=<RsubBackward1>)
# 45
# tensor(0.3723, grad_fn=<RsubBackward1>)
# 46
# tensor(0.3723, grad_fn=<RsubBackward1>)
# 47
# tensor(0.3723, grad_fn=<RsubBackward1>)
# 48
# tensor(0.3756, grad_fn=<RsubBackward1>)
# 49
# tensor(0.3769, grad_fn=<RsubBackward1>)
# 50
# tensor(0.3814, grad_fn=<RsubBackward1>)
# 51
# tensor(0.3835, grad_fn=<RsubBackward1>)
# 52
# tensor(0.3835, grad_fn=<RsubBackward1>)
# 53
# tensor(0.3798, grad_fn=<RsubBackward1>)
# 54
# tensor(0.3798, grad_fn=<RsubBackward1>)
# 55
# tensor(0.3780, grad_fn=<RsubBackward1>)
# 56
# tensor(0.3740, grad_fn=<RsubBackward1>)
# 57
# tensor(0.3740, grad_fn=<RsubBackward1>)
# 58
# tensor(0.3740, grad_fn=<RsubBackward1>)
# 59
# tensor(0.3740, grad_fn=<RsubBackward1>)
# 60
# tensor(0.3739, grad_fn=<RsubBackward1>)
# 61
# tensor(0.3710, grad_fn=<RsubBackward1>)
# 62
# tensor(0.3766, grad_fn=<RsubBackward1>)
# 63
# tensor(0.3773, grad_fn=<RsubBackward1>)
# 64
# tensor(0.3835, grad_fn=<RsubBackward1>)
# 65
# tensor(0.3835, grad_fn=<RsubBackward1>)
# 66
# tensor(0.3813, grad_fn=<RsubBackward1>)
# 67
# tensor(0.3744, grad_fn=<RsubBackward1>)
# 68
# tensor(0.3753, grad_fn=<RsubBackward1>)
# 69
# tensor(0.3763, grad_fn=<RsubBackward1>)
# 70
# tensor(0.3798, grad_fn=<RsubBackward1>)
# 71
# tensor(0.3766, grad_fn=<RsubBackward1>)
# 72
# tensor(0.3773, grad_fn=<RsubBackward1>)
# 73
# tensor(0.3773, grad_fn=<RsubBackward1>)
# 74
# tensor(0.3773, grad_fn=<RsubBackward1>)
# 75
# tensor(0.3766, grad_fn=<RsubBackward1>)
# 76
# tensor(0.3773, grad_fn=<RsubBackward1>)
# 77
# tensor(0.3773, grad_fn=<RsubBackward1>)
# 78
# tensor(0.3773, grad_fn=<RsubBackward1>)
# 79
# tensor(0.3785, grad_fn=<RsubBackward1>)
# 80
# tensor(0.3827, grad_fn=<RsubBackward1>)
# 81
# tensor(0.3830, grad_fn=<RsubBackward1>)
# 82
# tensor(0.3830, grad_fn=<RsubBackward1>)
# 83
# tensor(0.3814, grad_fn=<RsubBackward1>)
# 84
# tensor(0.3814, grad_fn=<RsubBackward1>)
# 85
# tensor(0.3814, grad_fn=<RsubBackward1>)
# 86
# tensor(0.3804, grad_fn=<RsubBackward1>)
# 87
# tensor(0.3812, grad_fn=<RsubBackward1>)
# 88
# tensor(0.3812, grad_fn=<RsubBackward1>)
# 89
# tensor(0.3812, grad_fn=<RsubBackward1>)
# 90
# tensor(0.3813, grad_fn=<RsubBackward1>)
# 91
# tensor(0.3819, grad_fn=<RsubBackward1>)
# 92
# tensor(0.3848, grad_fn=<RsubBackward1>)
# 93
# tensor(0.3832, grad_fn=<RsubBackward1>)
# 94
# tensor(0.3706, grad_fn=<RsubBackward1>)
# 95
# tensor(0.3621, grad_fn=<RsubBackward1>)
# 96
# tensor(0.3620, grad_fn=<RsubBackward1>)
# 97
# tensor(0.3620, grad_fn=<RsubBackward1>)
# 98
# tensor(0.3564, grad_fn=<RsubBackward1>)
# 99
# tensor(0.3557, grad_fn=<RsubBackward1>)

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix)

# %%
X = torch.from_numpy(X_train).float()
X.requires_grad=True
y = net(X)
s = silhouette(X, y)
y = y.detach().numpy()
X = X.detach().numpy()

color1 = (0, 0, 1)
color2 = (0, 1, 0)
color3 = (1, 0 , 0)
color4 = (0, 1 , 1)
color5 = (1, 1, 0)
color6 = (1, 0, 1)
colors = [color1, color2, color3, color4, color5, color6, color1, color2, color3, color4, color5, color6]

figure(figsize=(4, 4), dpi=300)
for i in range(y.shape[0]):
    color = [0, 0, 0]
    for j in range(y.shape[1]):
        color[0] = min(round(color[0] + y[i][j]*colors[j][0], 3), 1)
        color[1] = min(round(color[1] + y[i][j]*colors[j][1], 3), 1)
        color[2] = min(round(color[2] + y[i][j]*colors[j][2], 3), 1)
    color = tuple(color)
    plt.scatter(X[i,0], X[i,1], color=color)
plt.title(f'Neural Network - Clusters: {n_clusters} \n Purity Score: {purity_score(y_true, np.argmax(y, axis=-1)):.4f} \n NMI Score: {normalized_mutual_info_score(y_true, np.argmax(y, axis=-1)):.4f}\n Soft Silhuette Score: {s:.3f}')
plt.show()
# Out:
# <ipython-input-2-d90c5a287120>:32: UserWarning: Implicit dimension choice for softmin has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmin(self.fc2(x))

# %%
X = torch.from_numpy(X_train).float()
X.requires_grad=True

gm = GaussianMixture(n_components=n_clusters, random_state=0).fit(X_train)
probabilities = gm.predict_proba(X_train)
s = silhouette(X, torch.from_numpy(probabilities).float())
print(f'Mixture Model - Clusters: {n_clusters} \n Purity Score: {purity_score(y_true, np.argmax(probabilities, axis=-1))} \n Soft Silhouette Score: {s} \n NMI Score: {normalized_mutual_info_score(y_true, np.argmax(probabilities, axis=-1))}')
# Out:
# Mixture Model - Clusters: 2
#  Purity Score: 0.525
#  Soft Silhouette Score: 0.2666186988353729
#  NMI Score: 0.0018043668440533007

# %%
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(X_train)
print(f'Mixture Model - Clusters: {n_clusters} \n Purity Score: {purity_score(y_true, kmeans.labels_)}')
# Out:
# Mixture Model - Clusters: 2
#  Purity Score: 0.505
