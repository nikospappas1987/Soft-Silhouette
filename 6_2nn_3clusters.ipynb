# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.mixture import GaussianMixture
from sklearn import metrics
import random
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from matplotlib.pyplot import figure
from sklearn.cluster import KMeans

n_clusters = 3
k=6

center = 3
dev = 1
n_points = 100
cluster = [None]*6

cluster[0] = np.random.normal(0, dev, (n_points,2))
cluster[1] = np.random.normal(center, dev, (n_points,2))
cluster[2] = np.random.normal(-center, dev, (n_points,2))
cluster[3] = np.concatenate((np.random.normal(-center, dev, (n_points,1)),np.random.normal(center, dev, (n_points,1))), axis=1)
cluster[4] = np.concatenate((np.random.normal(-2*center, dev, (n_points,1)),np.random.normal(0, dev, (n_points,1))), axis=1)
cluster[5] = np.concatenate((np.random.normal(center, dev, (n_points,1)),np.random.normal(-center, dev, (n_points,1))), axis=1)

X_train = cluster[0]
for i in range(1,n_clusters):
    X_train = np.concatenate((X_train,cluster[i]))

X_train = shuffle(X_train, random_state=0)

plt.scatter(X_train[:,0], X_train[:,1], c='red')

# %%
import torch
from torch import nn, optim
import torch.nn.functional as F

device = torch.device("cpu")

class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, X_train):
        X = torch.from_numpy(X_train).float()
        X.requires_grad=True
        self.X = X.to(device)


    def __len__(self):
        return len(self.X)

    def __getitem__(self, index):
        return self.X[index]
    
train_data = CustomDataset(X_train)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=10*n_clusters)

class Net(nn.Module):

    def __init__(self, n_features):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_features, k, bias=True)
        self.fc2 = nn.Linear(k, n_clusters, bias=True)

    def forward(self, x):
        x = nn.functional.relu(self.fc1(x))
        return F.softmin(self.fc2(x))

net = Net(2)

net = net.to(device)

# %%
def silhouette(X, y):
    distances = torch.cdist(X, X, p=2)
    weighted_distances = torch.matmul(distances, y)
    sum_p = torch.sum(y, dim = 0)
    sum_p_mat = torch.empty(y.shape[0], y.shape[1])
    for i in range(y.shape[0]):
        sum_p_mat[i] = sum_p - y[i]
    alphas = torch.div(weighted_distances, sum_p)
    betas = torch.empty(alphas.shape[0], alphas.shape[1])
    betas = betas.to(device)
    for i in range(alphas.shape[0]):
        for j in range(alphas.shape[1]):
            betas[i][j] = min([alphas[i][x] for x in range(alphas.shape[1]) if x!=j])
    max_ab = torch.max(alphas, betas)
    s = betas - alphas
    s = torch.div(s, max_ab)
    s = s*y
    s = torch.sum(s, dim=1)
    s = torch.mean(s)
    return s

# %%
optimizer = optim.Adam(net.parameters(), lr=0.4)
train_data = CustomDataset(X_train)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=int(n_points*n_clusters/1))

for epoch in range(100):
    for n, X in enumerate(train_loader):
        y = net(X)
        y = torch.squeeze(y)
        s = silhouette(X, y)
        s = (1 - s)

        loss = s
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print(epoch)
    print(1 - s)
# Out:
# <ipython-input-2-78c702d926de>:32: UserWarning: Implicit dimension choice for softmin has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmin(self.fc2(x))
# 0
# tensor(-0.0416, grad_fn=<RsubBackward1>)
# 1
# tensor(-0.0165, grad_fn=<RsubBackward1>)
# 2
# tensor(0.2256, grad_fn=<RsubBackward1>)
# 3
# tensor(0.2699, grad_fn=<RsubBackward1>)
# 4
# tensor(0.2869, grad_fn=<RsubBackward1>)
# 5
# tensor(0.3686, grad_fn=<RsubBackward1>)
# 6
# tensor(0.4140, grad_fn=<RsubBackward1>)
# 7
# tensor(0.4596, grad_fn=<RsubBackward1>)
# 8
# tensor(0.5112, grad_fn=<RsubBackward1>)
# 9
# tensor(0.5682, grad_fn=<RsubBackward1>)
# 10
# tensor(0.4692, grad_fn=<RsubBackward1>)
# 11
# tensor(0.5772, grad_fn=<RsubBackward1>)
# 12
# tensor(0.5630, grad_fn=<RsubBackward1>)
# 13
# tensor(0.5421, grad_fn=<RsubBackward1>)
# 14
# tensor(0.5336, grad_fn=<RsubBackward1>)
# 15
# tensor(0.5311, grad_fn=<RsubBackward1>)
# 16
# tensor(0.5297, grad_fn=<RsubBackward1>)
# 17
# tensor(0.5293, grad_fn=<RsubBackward1>)
# 18
# tensor(0.5294, grad_fn=<RsubBackward1>)
# 19
# tensor(0.5300, grad_fn=<RsubBackward1>)
# 20
# tensor(0.5311, grad_fn=<RsubBackward1>)
# 21
# tensor(0.5329, grad_fn=<RsubBackward1>)
# 22
# tensor(0.5361, grad_fn=<RsubBackward1>)
# 23
# tensor(0.5396, grad_fn=<RsubBackward1>)
# 24
# tensor(0.5427, grad_fn=<RsubBackward1>)
# 25
# tensor(0.5455, grad_fn=<RsubBackward1>)
# 26
# tensor(0.5486, grad_fn=<RsubBackward1>)
# 27
# tensor(0.5542, grad_fn=<RsubBackward1>)
# 28
# tensor(0.5627, grad_fn=<RsubBackward1>)
# 29
# tensor(0.5690, grad_fn=<RsubBackward1>)
# 30
# tensor(0.5738, grad_fn=<RsubBackward1>)
# 31
# tensor(0.5808, grad_fn=<RsubBackward1>)
# 32
# tensor(0.5838, grad_fn=<RsubBackward1>)
# 33
# tensor(0.5844, grad_fn=<RsubBackward1>)
# 34
# tensor(0.5846, grad_fn=<RsubBackward1>)
# 35
# tensor(0.5847, grad_fn=<RsubBackward1>)
# 36
# tensor(0.5847, grad_fn=<RsubBackward1>)
# 37
# tensor(0.5850, grad_fn=<RsubBackward1>)
# 38
# tensor(0.5854, grad_fn=<RsubBackward1>)
# 39
# tensor(0.5855, grad_fn=<RsubBackward1>)
# 40
# tensor(0.5857, grad_fn=<RsubBackward1>)
# 41
# tensor(0.5857, grad_fn=<RsubBackward1>)
# 42
# tensor(0.5858, grad_fn=<RsubBackward1>)
# 43
# tensor(0.5858, grad_fn=<RsubBackward1>)
# 44
# tensor(0.5857, grad_fn=<RsubBackward1>)
# 45
# tensor(0.5854, grad_fn=<RsubBackward1>)
# 46
# tensor(0.5851, grad_fn=<RsubBackward1>)
# 47
# tensor(0.5850, grad_fn=<RsubBackward1>)
# 48
# tensor(0.5850, grad_fn=<RsubBackward1>)
# 49
# tensor(0.5850, grad_fn=<RsubBackward1>)
# 50
# tensor(0.5851, grad_fn=<RsubBackward1>)
# 51
# tensor(0.5852, grad_fn=<RsubBackward1>)
# 52
# tensor(0.5853, grad_fn=<RsubBackward1>)
# 53
# tensor(0.5855, grad_fn=<RsubBackward1>)
# 54
# tensor(0.5856, grad_fn=<RsubBackward1>)
# 55
# tensor(0.5857, grad_fn=<RsubBackward1>)
# 56
# tensor(0.5858, grad_fn=<RsubBackward1>)
# 57
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 58
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 59
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 60
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 61
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 62
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 63
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 64
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 65
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 66
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 67
# tensor(0.5858, grad_fn=<RsubBackward1>)
# 68
# tensor(0.5858, grad_fn=<RsubBackward1>)
# 69
# tensor(0.5858, grad_fn=<RsubBackward1>)
# 70
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 71
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 72
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 73
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 74
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 75
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 76
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 77
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 78
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 79
# tensor(0.5859, grad_fn=<RsubBackward1>)
# 80
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 81
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 82
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 83
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 84
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 85
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 86
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 87
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 88
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 89
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 90
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 91
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 92
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 93
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 94
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 95
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 96
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 97
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 98
# tensor(0.5860, grad_fn=<RsubBackward1>)
# 99
# tensor(0.5860, grad_fn=<RsubBackward1>)

# %%
y_true = []
for x in X_train:
    for i in range(len(cluster)):
        if len(np.where(cluster[i] == x)[0])>0:
            y_true.append(i)

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix)

# %%
X = torch.from_numpy(X_train).float()
X.requires_grad=True
y = net(X)
s = silhouette(X, y)
y = y.detach().numpy()
X = X.detach().numpy()

color1 = (0, 0, 1)
color2 = (0, 1, 0)
color3 = (1, 0 , 0)
color4 = (0, 1 , 1)
color5 = (1, 1, 0)
color6 = (1, 0, 1)
colors = [color1, color2, color3, color4, color5, color6, color1, color2, color3, color4, color5, color6]

figure(figsize=(4, 4), dpi=300)
for i in range(y.shape[0]):
    color = [0, 0, 0]
    for j in range(y.shape[1]):
        color[0] = min(round(color[0] + y[i][j]*colors[j][0], 3), 1)
        color[1] = min(round(color[1] + y[i][j]*colors[j][1], 3), 1)
        color[2] = min(round(color[2] + y[i][j]*colors[j][2], 3), 1)
    color = tuple(color)
    plt.scatter(X[i,0], X[i,1], color=color)
plt.title(f'Neural Network - Clusters: {n_clusters} \n Purity Score: {purity_score(y_true, np.argmax(y, axis=-1)):.4f} \n NMI Score: {normalized_mutual_info_score(y_true, np.argmax(y, axis=-1)):.4f}\n Soft Silhuette Score: {s:.3f}')
plt.show()
# Out:
# <ipython-input-2-78c702d926de>:32: UserWarning: Implicit dimension choice for softmin has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmin(self.fc2(x))

# %%
X = torch.from_numpy(X_train).float()
X.requires_grad=True

gm = GaussianMixture(n_components=n_clusters, random_state=0).fit(X_train)
probabilities = gm.predict_proba(X_train)
s = silhouette(X, torch.from_numpy(probabilities).float())
print(f'Mixture Model - Clusters: {n_clusters} \n Purity Score: {purity_score(y_true, np.argmax(probabilities, axis=-1))} \n Soft Silhouette Score: {s} \n NMI Score: {normalized_mutual_info_score(y_true, np.argmax(probabilities, axis=-1))}')
# Out:
# Mixture Model - Clusters: 3
#  Purity Score: 0.98
#  Soft Silhouette Score: 0.5786530375480652
#  NMI Score: 0.9149698270916867

# %%
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(X_train)
print(f'Mixture Model - Clusters: {n_clusters} \n Purity Score: {purity_score(y_true, kmeans.labels_)}')
# Out:
# Mixture Model - Clusters: 3
#  Purity Score: 0.98
